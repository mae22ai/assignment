# %% [markdown]
# ## 11. 파이썬 클래스
# 파이썬 클래스는 `타입`을 만들어내는 도구입니다. int, float, str과 같이 여러분의 새로운 타입을 만들 수 있습니다.

# %% [markdown]
# ### 251 클래스, 객체, 인스턴스
# 클래스와 객체에 대해 설명해주세요.

# %% [markdown]
# 정답: **클래스는 일종의 설계도로, 하나의 타입을 정의하는 방법입니다. 클래스에는 관련있는 데이터와 함수를 한 데 모아 정의할 수 있습니다. 클래스로 만들어진 결과물을 객체라고 합니다.**

# %% [markdown]
# ### 252 클래스 정의
# 비어있는 사람 (Human) 클래스를 "정의" 해보세요.

# %%
class Human:
    pass

# %% [markdown]
# ### 253 인스턴스 생성
# 사람 (Human) 클래스의 인스턴스를 "생성" 하고 이를 areum 변수로 바인딩해보세요.

# %%
class Human:
    pass

areum = Human()

# %% [markdown]
# ### 254 클래스 생성자-1
# 사람 (Human) 클래스에 "응애응애"를 출력하는 생성자를 추가하세요.\
# (💡hint: 생성자는 `__init__` 을 사용하여 만드는 메서드였죠? 복습해봅시다!)

# %%
class Human:
    def __init__(self):
        print("응애응애")

areum = Human()
# Out:
# 응애응애

# %% [markdown]
# ### 255 클래스 생성자-2
# 사람 (Human) 클래스에 (이름, 나이, 성별)을 받는 생성자를 추가하세요.

# %%
class Human:
    def __init__(self, name, age, sex):
        self.name = name
        self.age = age
        self.sex = sex

areum = Human("아름", 25, "여자")
print(areum.name)
# Out:
# 아름

# %% [markdown]
# ### 256 인스턴스 속성에 접근
# 255에서 생성한 인스턴스의 이름, 나이, 성별을 출력하세요. 인스턴스 변수에 접근하여 값을 출력하면 됩니다.

# %%
print("이름:", areum.name)
print("나이:", areum.age)
print("성별:", areum.sex)
# Out:
# 이름: 아름
# 나이: 25
# 성별: 여자

# %% [markdown]
# ### 257 클래스 메소드 - 1
# 사람 (Human) 클래스에서 이름, 나이, 성별을 출력하는 who() 메소드를 추가하세요.

# %%
class Human:
    def __init__(self, name, age, sex):
        self.name = name
        self.age = age
        self.sex = sex

    def who(self):
        print(f"이름:{self.name} 나이:{self.age} 성별:{self.sex}")
    

areum = Human("아름", 25, "여자")
areum.who()      # Human.who(areum)
# Out:
# 이름:아름 나이:25 성별:여자

# %% [markdown]
# ### 258 클래스 메소드 - 2
# 사람 (Human) 클래스에 (이름, 나이, 성별)을 받는 setInfo 메소드를 추가하세요.

# %%
class Human:
    def __init__(self, name, age, sex):
        self.name = name
        self.age = age
        self.sex = sex

    def who(self):
        print("이름: {} 나이: {} 성별: {}".format(self.name, self.age, self.sex))

    def setInfo(self, name, age, sex):
        self.name=name
        self.age=age
        self.sex=sex


areum = Human("불명", "미상", "모름")
areum.who()      # Human.who(areum)

areum.setInfo("아름", 25, "여자")
areum.who()      # Human.who(areum)
# Out:
# 이름: 불명 나이: 미상 성별: 모름
# 이름: 아름 나이: 25 성별: 여자

# %% [markdown]
# ### 259 클래스 소멸자
# 사람 (human) 클래스에 "나의 죽음을 알리지 말라"를 출력하는 소멸자를 추가하세요.\
# (💡hint: 소멸자는 `__del__(self):`로 정의하고, `del(객체)`로 호출할 수 있어요!)

# %%
class Human:
    def __init__(self, name, age, sex):
        self.name = name
        self.age = age
        self.sex = sex

    def __del__(self):
        print('나의 죽음을 알리지마라')

    def who(self):
        print("이름: {} 나이: {} 성별: {}".format(self.name, self.age, self.sex))

    def setInfo(self, name, age, sex):
        self.name = name
        self.age = age
        self.sex = sex

areum = Human("아름", 25, "여자")
print("📌 areum 객체 존재 여부 확인:", areum)
del(areum)
# Out:
# 📌 areum 객체 존재 여부 확인: <__main__.Human object at 0x000001B66F5A84F0>
# 나의 죽음을 알리지마라

# %%
print("📌 areum 객체 존재 여부 확인:", areum) # 소멸자 호출했기 때문에 객체가 삭제되었어요!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print("📌 areum 객체 존재 여부 확인:", areum)
#
# NameError: name 'areum' is not defined

# %% [markdown]
# ### 260 에러의 원인
# 아래와 같은 에러가 발생한 원인에 대해 간단히 설명하고, 올바른 코드로 고쳐 실행해주세요.
#
# ![image-2.png](attachment:image-2.png)
#
# (💡hint: 메서드를 호출하는 방법에 대해 복습해봅시다.
#
# (1) `mystock.print()`처럼 `객체.메서드`로 호출할 때는 self를 반드시 생략해서 호출해야 했습니다. 어라? 근데 self가 OMG 클래스의 print 메서드에 있나요?
#
# (2) (추가적으로 생각해봅시다)`클래스명.메서드`로 호출할 때에는 객체를 첫 번째 매개변수 self에 꼭 전달해야 한다고 했습니다. 이렇게 호출하려면 뭘 더 바꿔야 할까요?)

# %%
class OMG :
    def print() :
        print("Oh my god")


mystock = OMG()
mystock.print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       3         print("Oh my god")
#       6 mystock = OMG()
# ----> 7 mystock.print()
#
# TypeError: OMG.print() takes 0 positional arguments but 1 was given

# %% [markdown]
# **정답**: **print 메서드에 매개 변수가 없기 때문입니다 **

# %%
# 추가 : 왜 이렇게 했을까요? 생각해보세요!!
class OMG :
    def print(self) :
        print("Oh my god")


mystock = OMG()
OMG.print(mystock)
mystock.print()
# Out:
# Oh my god
# Oh my god

# %% [markdown]
# ### 261 Stock 클래스 생성
# 주식 종목에 대한 정보를 저장하는 Stock 클래스를 정의해보세요. 클래스는 속성과 메서드를 갖고 있지 않습니다.

# %%
class Stock:
    pass

# %% [markdown]
# ### 262 생성자
# Stock 클래스의 객체가 생성될 때 종목명과 종목코드를 입력 받을 수 있도록 생성자를 정의해보세요.

# %%
class Stock:
   def __init__(self, name, code):
      self.name=name
      self.code=code

삼성 = Stock("삼성전자", "005930")
print(삼성.name)
print(삼성.code)
# Out:
# 삼성전자
# 005930

# %% [markdown]
# ### 263 메서드
# 객체에 종목명을 입력할 수 있는 set_name 메서드를 추가해보세요.

# %%
class Stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

    def set_name(self, name):
        self.name=name

a = Stock(None, None)
a.set_name("삼성전자")  # Stock.set_name(a, "삼성전자")
print(a.name)
# Out:
# 삼성전자

# %% [markdown]
# ### 264 메서드
# 객체에 종목코드를 입력할 수 있는 set_code 메서드를 추가해보세요.

# %%
class Stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

    def set_name(self, name):
        self.name = name

    def set_code(self, code):
        self.code=code

a = Stock(None, None)
a.set_code("005930")
print(a.code)
# Out:
# 005930

# %% [markdown]
# ### 265 메서드
# 종목명과 종목코드를 리턴하는 get_name, get_code 메서드를 추가하세요. 해당 메서드를 사용하여 종목명과 종목코드를 얻고 이를 출력해보세요.

# %%
class Stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

    def set_name(self, name):
        self.name = name

    def set_code(self, code):
        self.code = code

    def get_name(self):
        return self.name
    def get_code(self):
        return self.code

    

삼성 = Stock("삼성전자", "005930")
print(삼성.name)
print(삼성.code)
print(삼성.get_name())
print(삼성.get_code())
# Out:
# 삼성전자
# 005930
# 삼성전자
# 005930

# %% [markdown]
# ### 266 객체의 속성값 업데이트
# 생성자에서 종목명, 종목코드, PER, PBR, 배당수익률을 입력 받을 수 있도록 생성자를 수정하세요. PER, PBR, 배당수익률은 float 타입입니다.

# %%
class Stock:
    def __init__(self, name, code, per, pbr, 배당수익률):
        self.name = name
        self.code = code
        self.per = per
        self.pbr = pbr
        self.배당수익률=배당수익률

    def set_name(self, name):
        self.name = name

    def set_code(self, code):
        self.code = code

    def get_name(self):
        return self.name

    def get_code(self):
        return self.code

# %% [markdown]
# ### 267 객체 생성
# 266번에서 정의한 생성자를 통해 다음 정보를 갖는 객체를 생성해보세요.
#
# |항목|정보|
# |---|---|
# |종목명|삼성전자|
# |종목코드|005930|
# |PER|15.79|
# |PBR|1.33|
# |배당수익률|2.83|

# %%
삼성 = Stock('삼성전자', '005930', 15.79, 1.33, 2.83)
print("종목명: {}, 종목코드: {}, PER: {}, PBR: {}, 배당수익률: {}".format(삼성.name, 삼성.code, 삼성.per, 삼성.pbr, 삼성.배당수익률))
# Out:
# 종목명: 삼성전자, 종목코드: 005930, PER: 15.79, PBR: 1.33, 배당수익률: 2.83

# %% [markdown]
# ### 268 객체의 속성 수정
# PER, PBR, 배당수익률은 변경될 수 있는 값입니다. 이 값을 변경할 때 사용하는 set_per, set_pbr, set_dividend 메서드를 추가하세요.

# %%
class Stock:
    def __init__(self, name, code, per, pbr, dividend):
        self.name = name
        self.code = code
        self.per = per
        self.pbr = pbr
        self.dividend = dividend

    def set_name(self, name):
        self.name = name

    def set_code(self, code):
        self.code = code

    def get_name(self):
        return self.name

    def get_code(self):
        return self.code

    **여기에 작성해주세요**

    **여기에 작성해주세요**
    
    **여기에 작성해주세요**

# %% [markdown]
# ### 269 객체의 속성 수정
# 267번에서 생성한 객체에 set_per 메서드를 호출하여 per 값을 12.75로 수정해보세요.

# %%
삼성 = Stock("삼성전자", "005930", 15.79, 1.33, 2.83)
삼성.***(12.75)
print(삼성.per)
# Out:
# 12.75

# %% [markdown]
# ### 270 여러 종목의 객체 생성
# 아래의 표를 참조하여 3종목에 대해 객체를 생성하고 이를 파이썬 리스트에 저장하세요. 파이썬 리스트에 저장된 각 종목에 대해 for 루프를 통해 종목코드와 PER을 출력해보세요.
#
# |종목명|종목코드|PER|PBR|배당수익률|
# |---|---|---|---|---|
# |삼성전자|005930|15.79|1.33|2.83|
# |현대차|005380|8.70|0.35|4.27|
# |LG전자|066570|317.34|0.69|1.37|

# %%
종목 = []

삼성 = Stock('삼성전자', '005930', 15.79, 1.33, 2.83)
현대차 = Stock('현대차', '005380', 8.70, 0.35, 4.27)
LG전자 = Stock('LG전자', '066570', 317.34, 0.69, 1.37)

종목.append(삼성) #리스트에 요소를 추가하려면 append 메서드를 쓰면 됐었죠!
종목.append(현대차)
종목.append(LG전자)

for i in 종목:
    print(i.code, i.per)        # i-> Stock 클래스의 객체를 바인딩하기 때문
# Out:
# 005930 15.79
# 005380 8.7
# 066570 317.34

# %% [markdown]
# ### 271 Account 클래스
# 은행에 가서 계좌를 개설하면 은행이름, 예금주, 계좌번호, 잔액이 설정됩니다. Account 클래스를 생성한 후 생성자를 구현해보세요. 생성자에서는 예금주와 초기 잔액만 입력 받습니다. 은행이름은 SC은행으로 계좌번호는 3자리-2자리-6자리 형태로 랜덤하게 생성됩니다.
#
# ```plain text
# 은행이름: SC은행
# 계좌번호: 111-11-111111
# ```

# %%
import random

class Account:
    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.bank = "SC은행"
        
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)      # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)      # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)      # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001

kim = Account("김민수", 100)
print(kim.name)
print(kim.balance)
print(kim.bank)
print(kim.account_number)
# Out:
# 김민수
# 100
# SC은행
# 271-23-896340

# %% [markdown]
# ### 272 클래스 변수
# 클래스 변수를 사용해서 Account 클래스로부터 생성된 계좌 객체의 개수를 저장하세요.

# %%
import random

class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)      # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)      # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)      # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001

        Account.account_count += 1


kim = Account("김민수", 100)
print(Account.account_count)
lee = Account("이민수", 100)
print(Account.account_count)
# Out:
# 1
# 2

# %% [markdown]
# ### 273 클래스 변수 출력
# Account 클래스로부터 생성된 계좌의 개수를 출력하는 get_account_num() 메서드를 추가하세요.

# %%
import random

class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)      # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)      # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)      # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count +=1

    @classmethod # 클래스메서드 @classmethod로 데코레이터 설정해주면 get_account_num 메서드 밖에 있는 클래스 변수에 접근 가능!
    def get_account_num(cls):
        print(cls.account_count)     # Account.account_count


kim = Account("김민수", 100)
lee = Account("이민수", 100)
kim.get_account_num()
# Out:
# 2

# %% [markdown]
# ### 274 입금 메서드
# Account 클래스에 입금을 위한 deposit 메서드를 추가하세요. 입금은 최소 1원 이상만 가능합니다.

# %%
import random

class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)      # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)      # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)      # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count +=1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)     # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

# %% [markdown]
# ### 275 출금 메서드
# Account 클래스에 출금을 위한 withdraw 메서드를 추가하세요. 출금은 계좌의 잔고 이상으로 출금할 수는 없습니다.

# %%
import random


class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)  # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)  # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

k = Account("kim", 100)
k.deposit(100)
k.withdraw(90)
print(k.balance)
# Out:
# 110

# %% [markdown]
# ### 276 정보 출력 메서드
# Account 인스턴스에 저장된 정보를 출력하는 display_info() 메서드를 추가하세요. 잔고는 세자리마다 쉼표를 출력하세요.
#
# ```plain text
# 은행이름: SC은행
# 예금주: 파이썬
# 계좌번호: 111-11-111111
# 잔고: 10,000원
# ```

# %%
import random


class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)  # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)  # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", f"{self.balance:,}")


p = Account("파이썬", 10000)
p.display_info()
# Out:
# 은행이름:  SC은행
# 예금주:  파이썬
# 계좌번호:  883-09-260378
# 잔고:  10,000

# %% [markdown]
# ### 277 이자 지급하기
# 입금 횟수가 5회가 될 때 잔고를 기준으로 1%의 이자가 잔고에 추가되도록 코드를 변경해보세요.

# %%
import random


class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.deposit_count = 0

        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)  # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)  # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         # 5, 10, 15
                # 이자 지금
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

p = Account("파이썬", 10000)
p.deposit(10000)
p.deposit(10000)
p.deposit(10000)
p.deposit(5000)
p.deposit(5000)
print(p.balance)
# Out:
# 50500.0

# %% [markdown]
# ### 278 여러 객체 생성
# Account 클래스로부터 3개 이상 인스턴스를 생성하고 생성된 인스턴스를 리스트에 저장해보세요.

# %%
import random


class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.deposit_count = 0

        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)  # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)  # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         # 5, 10, 15
                # 이자 지금
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

data = []
k = Account("KIM", 10000000) # 인스턴스를 생성해봅시다!
l = Account("LEE", 10000)
p = Account("PARK", 10000)

data.append(k) #append 메서드를 통해 리스트에 요소를 추가할 수 있었죠?
data.append(l)
data.append(p)

print(data)
# Out:
# [<__main__.Account object at 0x000001B66E23E530>, <__main__.Account object at 0x000001B66E23F520>, <__main__.Account object at 0x000001B66F560FA0>]

# %% [markdown]
# 리스트의 요소로 Account 객체 3개가 들어있는 것을 볼 수 있죠!!

# %% [markdown]
# ### 279 객체 순회
# 반복문을 통해 리스트에 있는 객체를 순회하면서 잔고가 100만원 이상인 고객의 정보만 출력하세요.

# %%
import random


class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.deposit_count = 0

        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)  # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)  # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         # 5, 10, 15
                # 이자 지금
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

data = []
k = Account("KIM", 10000000)
l = Account("LEE", 10000)
p = Account("PARK", 10000)
data.append(k)
data.append(l)
data.append(p)

for c in data:
    if c.balance >= 1000000:
        c.display_info()
# Out:
# 은행이름:  SC은행
# 예금주:  KIM
# 계좌번호:  610-71-630552
# 잔고:  10000000

# %% [markdown]
# ### 280 입출금 내역
# 입금과 출금 내역이 기록되도록 코드를 업데이트 하세요. 입금 내역과 출금 내역을 출력하는 deposit_history와 withdraw_history 메서드를 추가하세요.

# %%
import random


class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []

        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)  # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)  # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.deposit_log.append(amount)
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         # 5, 10, 15
                # 이자 지금
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.withdraw_log.append(amount)
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

    def withdraw_history(self):
        for amount in self.withdraw_log:
            print(amount)

    def deposit_history(self):
        for amount in self.deposit_log:
            print(amount)


k = Account("Kim", 1000)
k.deposit(100)
k.deposit(200)
k.deposit(300)
k.deposit_history()

k.withdraw(100)
k.withdraw(200)
k.withdraw_history()
# Out:
# 100
# 200
# 300
# 100
# 200

# %% [markdown]
# ### 281 클래스 정의
# 다음 코드가 동작하도록 차 클래스를 정의하세요.
#
# ```python
# >> car = 차(2, 1000)
# >> car.바퀴
# 2
# >> car.가격
# 1000
# ```

# %%
class 차:
    def __init__(self, 바퀴, 가격):
        self.바퀴=바퀴
        self.가격=가격


car = 차(2, 1000)
print(car.바퀴)
print(car.가격)
# Out:
# 2
# 1000

# %% [markdown]
# ### 282 클래스 상속
# 차 클래스를 상속받은 자전차 클래스를 정의하세요.

# %%
class 차:
   def __init__(self, 바퀴, 가격):
        self.바퀴=바퀴
        self.가격=가격

class 자전차(차):
    pass

# %% [markdown]
# ### 283 클래스 상속
# 다음 코드가 동작하도록 자전차 클래스를 정의하세요. 단 자전차 클래스는 차 클래스를 상속받습니다.
#
# ```python
# >> bicycle = 자전차(2, 100)
# >> bicycle.가격
# 100
# ```

# %%
class 차:
    def __init__(self, 바퀴, 가격):
        self.바퀴 = 바퀴
        self.가격 = 가격


class 자전차(차):
    pass


bicycle = 자전차(2, 100)
print(bicycle.가격)
# Out:
# 100

# %% [markdown]
# ### 284 클래스 상속
# 다음 코드가 동작하도록 자전차 클래스를 정의하세요. 단 자전차 클래스는 차 클래스를 상속받습니다.
# ```python
# >> bicycle = 자전차(2, 100, "시마노")
# >> bicycle.구동계
# 시마노
# ```

# %%
class 차:
    def __init__(self, 바퀴, 가격):
        self.바퀴 = 바퀴
        self.가격 = 가격


class 자전차(차):
    def __init__(self, 바퀴, 가격, 구동계):
        self.바퀴=바퀴
        self.가격=가격
        self.구동계=구동계


bicycle = 자전차(2, 100, "시마노")
print(bicycle.구동계)
print(bicycle.바퀴)
# Out:
# 시마노
# 2

# %% [markdown]
# ### 285 클래스 상속
# 다음 코드가 동작하도록 차 클래스를 상속받는 자동차 클래스를 정의하세요.
#
# ```python
# >> car = 자동차(4, 1000)
# >> car.정보()
# 바퀴수 4
# 가격 1000
# ```

# %%
class 차:
    def __init__(self, 바퀴, 가격):
        self.바퀴 = 바퀴
        self.가격 = 가격


class 자동차(차):
    def __init__(self, 바퀴, 가격):
        super().__init__(바퀴, 가격) 

    
def 정보(self):
        print("바퀴수 ", self.바퀴)
        print("가격 ", self.가격)

car = 자동차(4, 1000)
car.정보()
# Out:
# 바퀴수  4
# 가격  1000

# %% [markdown]
# ### 286 부모 클래스 생성자 호출
# 다음 코드가 동작하도록 `차` 클래스를 수정하세요.
#
# ```python
# >> bicycle = 자전차(2, 100, "시마노")
# >> bicycle.정보()
# 바퀴수 2
# 가격 100
# ```

# %%
class 차:
    def __init__(self, 바퀴, 가격):
        self.바퀴=바퀴
        self.가격=가격
    def 정보(self):
        print("바퀴수 ", self.바퀴)
        print("가격 ", self.가격)

class 자동차(차):
    def __init__(self, 바퀴, 가격):
        super().__init__(바퀴, 가격)

class 자전차(차):
    def __init__(self, 바퀴, 가격, 구동계):
        super().__init__(바퀴, 가격)
        self.구동계 = 구동계

bicycle = 자전차(2, 100, "시마노")
bicycle.정보()
# Out:
# 바퀴수  2
# 가격  100

# %% [markdown]
# ### 287 부모 클래스 메서드 호출
# 자전차의 정보() 메서드로 구동계 정보까지 출력하도록 수정해보세요.
# ```python
# >> bicycle = 자전차(2, 100, "시마노")
# >> bicycle.정보()
# 바퀴수 2
# 가격 100
# 구동계 시마노
# ```

# %%
class 차:
    def __init__(self, 바퀴, 가격):
        self.바퀴 = 바퀴
        self.가격 = 가격

    def 정보(self):
        print("바퀴수 ", self.바퀴)
        print("가격 ", self.가격)

class 자동차(차):
    def __init__(self, 바퀴, 가격):
        super().__init__(바퀴, 가격)

class 자전차(차):
    def __init__(self, 바퀴, 가격, 구동계):
        super().__init__(바퀴, 가격)
        self.구동계 = 구동계

    def 정보(self):
        super().정보()
        print("구동계 ", self.구동계)

bicycle = 자전차(2, 100, "시마노")
bicycle.정보()
# Out:
# 바퀴수  2
# 가격  100
# 구동계  시마노

# %% [markdown]
# ### 288 메서드 오버라이딩
# 다음 코드의 실행 결과를 예상해보세요.
# ```python
# class 부모:
#   def 호출(self):
#     print("부모호출")
#
# class 자식(부모):
#   def 호출(self):
#     print("자식호출")
#
# 나 = 자식()
# 나.호출()
# ```

# %% [markdown]
# **정답**: 자식호출

# %% [markdown]
# ### 289 생성자
# 다음 코드의 실행 결과를 예상해보세요.
# ```python
# class 부모:
#   def __init__(self):
#     print("부모생성")
#
# class 자식(부모):
#   def __init__(self):
#     print("자식생성")
#
# 나 = 자식()
# ```

# %% [markdown]
# **정답**: 자식생성

# %% [markdown]
# ### 290 부모클래스 생성자 호출
# 다음 코드의 실행 결과를 예상해보세요.
#
# ```python
# class 부모:
#   def __init__(self):
#     print("부모생성")
#
# class 자식(부모):
#   def __init__(self):
#     print("자식생성")
#     super().__init__()
#
# 나 = 자식()
# ```

# %% [markdown]
# **정답**:
#
# **여기에 적어주세요 **

# %%
class 부모:
  def __init__(self):
    print("부모생성")

class 자식(부모):
  def __init__(self):
    print("자식생성")
    super().__init__()

나 = 자식()
# Out:
# 자식생성
# 부모생성
